# %% [markdown]
# $
# \textbf{QUESTION 1} \\
# $
# $$
# \text{Variable Descriptions:} \\
# y_i \in \{0,1\} \ \forall \ i = 1, 2, 3 \\
# x_i \text{ is the number of cars for the i-th type} \rightarrow \\ \forall \ i = 1, 2, 3 \rightarrow \\ x \in \mathbb{Z_{+}} \\
# M_{car} \text{ is the number of cars produced given the available hours and labor hours required} \rightarrow \\
# \forall \ car = c, m, l \rightarrow \\
# \text{c = Compact, m = Midsize, l = Large, t = Total} \rightarrow \\
# M_c = 2000 \rightarrow \\
# M_m = 2400 \rightarrow \\
# M_l = 1500 \rightarrow \\
# M_{t} = 3200\\
# p_i = \text{profit from each car} \rightarrow \\
# \forall \ i = 1, 2, 3 \\
# l_i = \text{Labor required for each car} \rightarrow \\
# \forall \ i = 1, 2, 3 \\
# s_i = \text{Steel required for each car} \rightarrow \\
# \forall \ i = 1, 2, 3
# \\~\\
#
# \text{Objective Function:} \\
# \max \sum p_ix_1 \\~\\
#
# \text{Constraints:} \\
# \sum_{i = 1}^{3} l_ix_i \le 60000 \\
# \sum_{i = 1}^{3} s_ix_i \le 6000 \\
# x_1 + x_2 \le 1200 + M_{t}(1 - y_3)\\
# 1000y_1 \le x_1 \le M_1 y_1 \\
# 800y_2 \le x_2 \le M_2 y_2 \\
# x_3 \le M_3 y_3 \\
#
#
# $$

# %% [markdown]
# $\textbf{QUESTION 2}$
#
# $$
# \text{Variable Description:}\\
# x_i \rightarrow \text{number of workers who start work on a day} \rightarrow \\
#  \forall \ i = 1,...,7 \rightarrow x_i \in \mathbb{Z} \\
# \text{Assume: } x_1 = \text{Monday; } x_7 = \text{Sunday}\\
# c_i = \text{cost of the day for a worker}\\
# y_i \in \{0,1\} \\
# s \in \{0,1\} \\
# t \in \{0,1\} \\~\\
#
# \text{Objective Function:}\\
# \min \sum_{i=1}^{7} c_i x_{i} \\~\\
#
# \text{Constraints:}\\
# \sum_{i=1}^{5} x_i \ge 25 \\
# \sum_{i=2}^{6} x_i \ge 25 \\
# \sum_{i=3}^{7} x_i \ge 25 \\
# \sum_{i\in \{4, 5, 6, 7, 1\}} x_i \ge 25 \\
# \sum_{i\in \{5, 6, 7, 1, 2\}} x_i \ge 25 \\
# \sum_{i\in \{6, 7, 1, 2, 3\}} x_i \ge 25 \\
# \sum_{i\in \{7, 1, 2, 3, 4\}} x_i \ge 25 \\
# \sum_{i=1}^{5} x_{i} \le 5(1 - y_i) + 35 \\
# \sum_{i=2}^{6} x_{i} \le 5(1 - y_i) + 35 \\
# \sum_{i=3}^{7} x_{i} \le 5(1 - y_i) + 35 \\
# \sum_{i \in \{4, 5, 6, 7, 1\}} x_{i} \le 5(1 - y_i) + 35 \\
# \sum_{i \in \{5, 6, 7, 1, 2\}} x_{i} \le 5(1 - y_i) + 35 \\
# \sum_{i \in \{6, 7, 1, 2, 3\}} x_{i} \le 5(1 - y_i) + 35 \\
# \sum_{i \in \{7, 1, 2, 3, 4\}} x_{i} \le 5(1 - y_i) + 35 \\
# x_1 \le 30s + 10 \\
# x_1 + x_2 + x_3 + x_6 + x_7 \le 12(1 - s) + 28 \\
# x_6 \le 40t + x_1 - 1 \\
# x_6 \le 40(1 - t) + x_2 - 1 \\
# \sum_{i=1}^{7} x_i \le 40
# $$

# %% [markdown]
# $
# \textbf{QUESTION 3}
# $
#
# $$
# \text{Variable Description:}\\
# r_{i,t} \text{ is the revenue for game i on day t} \\
# x_{i,t} \in \{0, 1\} \text{ is a binary variable denoting if a game is scheduled on a day}
#
#
# \\~\\
# \text{Objective Function:}\\
# \max \sum_{i = 1}^{6} \sum_{t = 1}^{3} r_{i,t}x_{i,t}
#
# \\~\\
# \text{Constraints:}\\
# \sum_{t = 1}^{3} x_{1,t} = 1 \\
# \sum_{t = 1}^{3} x_{2,t} = 1 \\
# \sum_{t = 1}^{3} x_{3,t} = 1 \\
# \sum_{t = 1}^{3} x_{4,t} = 1 \\
# \sum_{t = 1}^{3} x_{5,t} = 1 \\
# \sum_{t = 1}^{3} x_{6,t} = 1 \\
# \sum_{i = 1}^{3} x_{i, 1} \le 2 \\
# \sum_{i = 1}^{3} x_{i, 2} \le 2 \\
# \sum_{i = 1}^{3} x_{i, 3} \le 2 \\
# \sum_{i \in \{2, 5, 6\}} x_{i,1} \le 2 \\
# \sum_{i \in \{2, 5, 6\}} x_{i,2} \le 2 \\
# \sum_{i \in \{2, 5, 6\}} x_{i,3} \le 2 \\
# x_{4,1} = 0 \\
# x_{5,1} = 0 \\
# \sum_{i = 1}^{6} x_{i,3} \ge 2 \\
# x_{1,1} \le 1 - x_{6,3} + x_{5, 2}
#
#
# $$
